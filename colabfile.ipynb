# %%
a = 10
b = 3

# %%
a+b
# Out:
# 13

# %%
print("""
The idea is to help students use VSCODE directly from browser.

With CookieCloud Labs, you can:

• Open VS Code directly in your browser
• Access a pre-configured AI environment
• Practice AI and MLOps workflows
• Focus on building instead of debugging installations

Along with that, I’ll be launching a small founding engineering cohort.

The structure would be simple:
Three days a week — we’ll focus on structured AI learning.
Three days — you’ll work on real GitHub repositories, documentation, and 
improving the lab environment.
Fully remote. Flexible. Practical.

This wouldn't be a random free class.
It’d be for serious students who want real implementation experience.

If you’re genuinely interested in learning AI properly — and 
building something real — you can reach out to me directly on WhatsApp.
9582025965

I’m selecting only 5–6 committed students for the pilot batch.

Let’s build, not just watch tutorials.




    """)
# Out:
# The idea is to help students use VSCODE directly from browser.
#
# With CookieCloud Labs, you can:
#
# • Open VS Code directly in your browser
# • Access a pre-configured AI environment
# • Practice AI and MLOps workflows
# • Focus on building instead of debugging installations
#
# Along with that, I’ll be launching a small founding engineering cohort.
#
# The structure would be simple:
# Three days a week — we’ll focus on structured AI learning.
# Three days — you’ll work on real GitHub repositories, documentation, and
# improving the lab environment.
# Fully remote. Flexible. Practical.
#
# This wouldn't be a random free class.
# It’d be for serious students who want real implementation experience.
#
# If you’re genuinely interested in learning AI properly — and
# building something real — you can reach out to me directly on WhatsApp.
# 9582025965
#
# I’m selecting only 5–6 committed students for the pilot batch.
#
# Let’s build, not just watch tutorials.
